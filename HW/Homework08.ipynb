# %% [markdown]
# # Problem 1
#
# Use HEC-RAS to reproduce the channel and backwater conditions found
# in the tutorial by Dr. Liu (“HEC-RAS BackwaterExample.pdf”). Include a
# printout of the longitudinal profile and the cross section located 200 ft upstream of the downstream control. Compare the longitudinal profile produced by HEC-RAS to one computed with your own direct or standard step
# solver or spreadsheet (you should be able to use a spreadsheet or piece of
# code from the previous homework). How does everything change when the
# flow is reduced to Q = 50 cfs?

# %% [markdown]
# ## 1a. Longitudinal Profile (100cfs)
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 1b. Profile 200ft upstream of downstream boundary condition (100 cfs)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1c. Longitudinal Profile of Standard Step Solver (100 cfs)

# %% [markdown]
# ## 1d. Comparison of HEC longitudinal profile and Solver profile (100 cfs)

# %% [markdown]
# ## 1e. How does everything change when Q = 50 cfs

# %% [markdown]
# ## 1f. Longitudinal Profile (50cfs)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1g. Profile 200ft upstream of downstream boundary condition (50 cfs)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1h. Longitudinal Profile of Standard Step Solver (50 cfs)

# %% [markdown]
# ## 1i.  Comparison of HEC longitudinal profile and Solver profile (50 cfs)

# %% [markdown]
# # Problem 2
# Use HEC-RAS and the cross section data found in the file: “LostCreek XS.xlsx”
# to build a model of an approximately 1 mile stretch of Lost Creek (the data,
# and part of this question, come from the University of Texas at Austin). Take
# the within channel Manning n value to be 0.035 and the overbank n value to
# be 0.045.

# %% [markdown]
# ## 2a.
# Assume that the downstream depth is normal and examine the depths and velocities in the reach during a 100 yr event of Q = 3000 cfs. Report the longitudinal profile of depth and velocity, the oblique view of the river depth within the reach, and the cross section data at XS1, XS3, XS5, XS7, XS9, and XS11

# %% [markdown]
# ### Longitudinal Profile of depth and velocity
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Oblique view of river depth within reach
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS1
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS3
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS5
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS7
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS9
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### XS11
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2b.
# Where does flooding occur within the reach? Why does it occur where it does and not throughout the entirety of the reach?

# %% [markdown]
# ## 2c.
# Repeat the analysis, but now use a downstream water surface elevation of $y_{ds−elev}$. = 1767 ft; let’s say the depth increased in the cross section due to a choke flow condition in a set of box culverts just downstream of XS1. Does the rise in the water surface elevation at XS1 increase flooding? Show quantitative data and explain why or why not the choke impacted the flooding.
